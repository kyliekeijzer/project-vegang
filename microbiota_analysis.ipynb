# %% [markdown]
# # Microbiota analysis
# ## Author: Tijs van Lieshout

# %% [markdown]
# ### Import statements:

# %%
import pandas as pd
import glob
from bokeh.plotting import figure, show
from bokeh.layouts import gridplot
from bokeh.models import Range1d
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Loading the data:

# %%
def load_data_microbiota(PATH):
    """Load microbiota data (Gut Feeling Knowledge Base and metaphlann output) into pandas 
    dataframes

    Keyword arguments:
    PATH -- The path which contains the Gut Feeling Knowledge Base and metaphlann output dir
    
    Returns:
    gfkb -- A pandas dataframe containing the Gut Feeling Knowledge Base
    tax_profiles -- A list of pandas dataframes containing the taxonomic profile per barcode
    """
    gfkb = pd.read_csv(f"{PATH}/GutFeelingKnowledgeBase-v4-Master_List.csv")
    gfkb = gfkb.drop(columns=["Present in GFKB v3 (Y/N)",
                              "Present in GFKB_epilepsy v3 (Y/N)"])
    gfkb = pd.concat([gfkb.drop(columns=["Genome Size (Mb)"]).apply(lambda x: x.astype(str)), 
                      gfkb["Genome Size (Mb)"]], axis=1)
#     print(gfkb['Effect/Function'].value_counts())

    tax_profiles = []
    for file in glob.glob(f"{PATH}/metaphlan_output/*.txt"):
        tax_profile = pd.read_csv(file, 
                                  comment="#", 
                                  sep="\t", 
                                  names=["clade_name", 
                                         "NCBI_tax_id", 
                                         "relative_abundance", 
                                         "additional_species"])
        tax_profiles.append(tax_profile)
    
    return gfkb, tax_profiles

# %% [markdown]
# ### Plotting data

# %%
def recreate_zimmer(tax_profiles):
    for tax_profile in tax_profiles:
        tax_of_interest = tax_profile[tax_profile.clade_name.str.contains("Bacteroides")]
        print(tax_of_interest)
    return

# %%
def main():
    PATH = "../microbiota_tax_data"
    gfkb, tax_profiles = load_data_microbiota(PATH)
    recreate_zimmer(tax_profiles)

if __name__ == '__main__':
    main()
# Out:
#                                            clade_name  \
# 34  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 49  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 54  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 55  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                            NCBI_tax_id  relative_abundance  \
# 34         2|976|200643|171549|815|816           11.142482
# 49     2|976|200643|171549|815|816|820            8.483781
# 54  2|976|200643|171549|815|816|357276            1.393951
# 55   2|976|200643|171549|815|816|46506            1.264750
#
#                                    additional_species
# 34                                                NaN
# 49  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 54  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 55                                                NaN
# Empty DataFrame
# Columns: [clade_name, NCBI_tax_id, relative_abundance, additional_species]
# Index: []
# Empty DataFrame
# Columns: [clade_name, NCBI_tax_id, relative_abundance, additional_species]
# Index: []
#                                            clade_name  \
# 24  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 35  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 36  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 37  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 39  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 42  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 43  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                            NCBI_tax_id  relative_abundance  \
# 24         2|976|200643|171549|815|816           72.359702
# 35     2|976|200643|171549|815|816|820           36.784192
# 36     2|976|200643|171549|815|816|821           20.302266
# 37   2|976|200643|171549|815|816|28116            9.093830
# 39  2|976|200643|171549|815|816|626929            3.183909
# 42     2|976|200643|171549|815|816|817            1.706326
# 43     2|976|200643|171549|815|816|818            1.289179
#
#                                    additional_species
# 24                                                NaN
# 35  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 36  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 37  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 39  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 42  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 43  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#                                           clade_name  \
# 6  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 7  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 8  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                          NCBI_tax_id  relative_abundance  \
# 6        2|976|200643|171549|815|816            4.673976
# 7    2|976|200643|171549|815|816|821            3.745259
# 8  2|976|200643|171549|815|816|46506            0.928717
#
#                                   additional_species
# 6                                                NaN
# 7  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 8                                                NaN
#                                            clade_name  \
# 39  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 64  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 74  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 76  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 88  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 96  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 98  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                            NCBI_tax_id  relative_abundance  \
# 39         2|976|200643|171549|815|816           11.504069
# 64     2|976|200643|171549|815|816|820            8.779574
# 74  2|976|200643|171549|815|816|357276            1.094294
# 76   2|976|200643|171549|815|816|46506            0.780766
# 88   2|976|200643|171549|815|816|47678            0.450608
# 96   2|976|200643|171549|815|816|28116            0.246705
# 98  2|976|200643|171549|815|816|387090            0.152127
#
#                                    additional_species
# 39                                                NaN
# 64  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 74  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 76                                                NaN
# 88  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 96  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 98  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#                                            clade_name  \
# 17  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 22  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 28  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                            NCBI_tax_id  relative_abundance  \
# 17         2|976|200643|171549|815|816           20.060296
# 22  2|976|200643|171549|815|816|310297           19.902107
# 28     2|976|200643|171549|815|816|821            0.158181
#
#                                    additional_species
# 17                                                NaN
# 22  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 28  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# Empty DataFrame
# Columns: [clade_name, NCBI_tax_id, relative_abundance, additional_species]
# Index: []
#                                            clade_name  \
# 12  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 16  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 17  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 18  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 21  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 23  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                           NCBI_tax_id  relative_abundance  \
# 12        2|976|200643|171549|815|816           57.323816
# 16    2|976|200643|171549|815|816|820           24.703969
# 17    2|976|200643|171549|815|816|821           17.565363
# 18  2|976|200643|171549|815|816|28116           12.339349
# 21    2|976|200643|171549|815|816|818            2.234886
# 23    2|976|200643|171549|815|816|817            0.480255
#
#                                    additional_species
# 12                                                NaN
# 16  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 17  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 18  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 21  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 23  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#                                            clade_name  \
# 19  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 27  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 28  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 29  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 37  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 40  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#
#                            NCBI_tax_id  relative_abundance  \
# 19         2|976|200643|171549|815|816           21.217306
# 27     2|976|200643|171549|815|816|821            7.913108
# 28   2|976|200643|171549|815|816|46506            6.516075
# 29     2|976|200643|171549|815|816|820            6.237333
# 37  2|976|200643|171549|815|816|338188            0.489845
# 40   2|976|200643|171549|815|816|28116            0.060948
#
#                                    additional_species
# 19                                                NaN
# 27  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 28                                                NaN
# 29  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# 37                                                NaN
# 40  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
#                     clade_name  NCBI_tax_id  relative_abundance  \
# 0        Bacteroides_sp_4_1_36          NaN                 NaN
# 1       Bacteroides_sp_3_1_40A          NaN                 NaN
# 2      Bacteroides_sp_AF32_8BH          NaN                 NaN
# 4         Bacteroides_sp_44_46          NaN                 NaN
# 7  Bacteroides_fragilis_CAG_47          NaN                 NaN
# 8        Bacteroides_sp_1_1_14          NaN                 NaN
# 9        Bacteroides_sp_CAG_20          NaN                 NaN
#
#    additional_species
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 4                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
